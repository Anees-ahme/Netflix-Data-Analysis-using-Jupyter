# %%
# importing Libraries
import pandas as pd
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'archive',
#  'archive (2)',
#  'archive (2).zip',
#  'archive.zip',
#  'Netflix Data Analysis.ipynb',
#  'Netflix Userbase.csv',
#  'netflix1.csv',
#  'netflix_titles.csv',
#  'Untitled.ipynb']

# %%
#Loading Dataset
df='netflix1.csv'
data=pd.read_csv(df)
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
#checking the data type of columns
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
data.head()       #use Head() function To show top 5 records
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data.tail()             #use tail() function To show last 5 records
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
data.shape    # To show Number of Rows and Columns in dataset
# Out:
# (8790, 10)

# %%
data.size     # To show the total Number of Records or Items in dataset
# Out:
# 87900

# %%
data.columns  # To show the Total Numbers of Columns in dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
data.dtypes  # To show the data type of all columns in dataset
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
data.info()      #To show the all information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
data.duplicated()    #checking the duplication in the dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8785    False
# 8786    False
# 8787    False
# 8788    False
# 8789    False
# Length: 8790, dtype: bool

# %%
data[data.duplicated()]    # Checking row-wise duplicate data, Here it show no duplicate record
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
data.drop_duplicates(inplace=True)    # Use it to remove the duplicates, if any

# %%
data.isnull()   # for checking the null values in dataset
# Out:
#       show_id   type  title  director  country  date_added  release_year  \
# 0       False  False  False     False    False       False         False
# 1       False  False  False     False    False       False         False
# 2       False  False  False     False    False       False         False
# 3       False  False  False     False    False       False         False
# 4       False  False  False     False    False       False         False
# ...       ...    ...    ...       ...      ...         ...           ...
# 8785    False  False  False     False    False       False         False
# 8786    False  False  False     False    False       False         False
# 8787    False  False  False     False    False       False         False
# 8788    False  False  False     False    False       False         False
# 8789    False  False  False     False    False       False         False
#
#       rating  duration  listed_in
# 0      False     False      False
# ...

# %%
data.isnull().sum()    # checking count of all null values columns wise
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
import seaborn as sns     # importing seaborn library to show heaatmap of null values

# %%
sns.heatmap(data.isnull())    # drawing heatmap of null values
# Out:
# <Axes: >

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data['title']      # looking for specific columns like here it is title columns
# Out:
# 0                   Dick Johnson Is Dead
# 1                              Ganglands
# 2                          Midnight Mass
# 3       Confessions of an Invisible Girl
# 4                                Sankofa
#                       ...
# 8785                          Yunus Emre
# 8786                           Zak Storm
# 8787                  Zindagi Gulzar Hai
# 8788                                Yoko
# 8789                                 YOM
# Name: title, Length: 8790, dtype: object

# %%
data['title'].isin(['Zubaan'])      # checking the 'Zubaan' title in the dataset if availble it will be True else false
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8785    False
# 8786    False
# 8787    False
# 8788    False
# 8789    False
# Name: title, Length: 8790, dtype: bool

# %%
data[data['title'].isin(['Zubaan'])]     #checking for specific location where required title located
# Out:
#      show_id   type   title     director country date_added  release_year  \
# 6544   s8807  Movie  Zubaan  Mozez Singh   India   3/2/2019          2015
#
#      rating duration                                       listed_in
# 6544  TV-14  111 min  Dramas, International Movies, Music & Musicals

# %%
data.dtypes      # checking datatypes of columns because we have to find in which year higghest Number of movies were released
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
data['R_Date']=pd.to_datetime(data['date_added'])     # we are creating new column here in dataset "R_Date" that takes values from 'release_year'

# %%
data.head()     #checking again new column created
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in     R_Date
# 0                                      Documentaries 2021-09-25
# ...

# %%
data.dtypes     #checking datatype of columns again and you can see 'R_Date' have datetime data type that we want to produce
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# R_Date          datetime64[ns]
# dtype: object

# %%
data['R_Date'].dt.year.value_counts()        #applying function 'dt.year.value_counts()' to count highest movies released in which year
# Out:
# R_Date
# 2019    2016
# 2020    1879
# 2018    1648
# 2021    1498
# 2017    1185
# 2016     426
# 2015      82
# 2014      24
# 2011      13
# 2013      11
# 2012       3
# 2009       2
# 2008       2
# 2010       1
# Name: count, dtype: int64

# %%
data['R_Date'].dt.year.value_counts().plot(kind='bar')    # by using new column to make bar charrt
# Out:
# <Axes: xlabel='R_Date'>

# %%
data.head(2)    #show top 2 rows of dataset
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date
# 0                                      Documentaries 2021-09-25
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24

# %%
data.groupby('type').type.count()   # using groupby function to group all unique items of the column and there count
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: type, dtype: int64

# %%
 sns.countplot(data['type'])      #using countplot function to show items in bar graph
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date
# 0                                      Documentaries 2021-09-25
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24

# %%
data['Year']=data['R_Date'].dt.year     # Now we are creating a new column name 'Year' from column "R_Date" and new column only contain year

# %%
data.head(2)    #checking for new column
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
data[(data['type']=='Movie') & (data['Year']==2021)]    #apply filtering to filter 'Movie' from 'type' column & '2021' from 'Year' column
# Out:
#      show_id   type                                     title  \
# 0         s1  Movie                      Dick Johnson Is Dead
# 3        s14  Movie          Confessions of an Invisible Girl
# 4         s8  Movie                                   Sankofa
# 6        s10  Movie                              The Starling
# 7       s939  Movie           Motu Patlu in the Game of Zones
# ...      ...    ...                                       ...
# 6826   s1162  Movie  Elizabeth and Margaret: Love and Loyalty
# 6862   s1288  Movie      Fate: The Winx Saga - The Afterparty
# 6906   s1426  Movie               Creating The Queen's Gambit
# 6910   s1432  Movie                               Stuck Apart
# 6922   s1467  Movie              The Minimalists: Less Is Now
#
#              director         country date_added  release_year rating  \
# 0     Kirsten Johnson   United States  9/25/2021          2020  PG-13
# 3       Bruno Garotti          Brazil  9/22/2021          2021  TV-PG
# ...

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
#Filtering again the 'titles' of the 'Movies' that were only released in 'France'
data[(data['type']=='Movie') & (data['country']=='France')] ['title']
# Out:
# 112          The Women and the Murderer
# 174     Agatha Christie's Crooked House
# 258                    2 Alone in Paris
# 411                           The Swarm
# 509                     Eyes of a Thief
#                      ...
# 6186                  The Last Exorcism
# 6196                  The Little Prince
# 6340                       The Workshop
# 6496                             Winnie
# 6522                         Yellowbird
# Name: title, Length: 148, dtype: object

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
#Top 10 Director who gave Highest Number of Movies and Tv Shows to Netflix
data['director'].value_counts().head(10)
# Out:
# director
# Not Given                 2588
# Rajiv Chilaka               20
# Alastair Fothergill         18
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Name: count, dtype: int64

# %%
data.head(3)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021
# 2                 TV Dramas, TV Horror, TV Mysteries 2021-09-24  2021

# %%
# Fliteering again where 'type' is 'Movie' and 'listed_in''Comedies'
data [(data['type']=='Movie') & (data['listed_in']=='Comedies') ]
# Out:
#      show_id   type                                      title  \
# 16      s913  Movie                The Circle - The Afterparty
# 30       s28  Movie                                  Grown Ups
# 183    s1029  Movie  Dad Stop Embarrassing Me - The Afterparty
# 185     s153  Movie              Janoskians: Untold and Untrue
# 253     s183  Movie                Welcome Home Roscoe Jenkins
# ...      ...    ...                                        ...
# 6824   s1158  Movie                                   Bad Trip
# 7610   s3630  Movie                                  Otherhood
# 7697   s3828  Movie        Still LAUGH-IN: The Stars Celebrate
# 7957   s4696  Movie      Party Monster: Scratching the Surface
# 7976   s4762  Movie                         Father of the Year
#
#                              director         country date_added  \
# 16    Krysia Plonka, Kristian Mercado   United States   5/7/2021
# 30                       Dennis Dugan   United States  9/20/2021
# ...

# %%
# Fliteering again where 'type' is 'Movie' and 'listed_in''Comedies' or 'country' should be 'United Kingdom'
data [(data['type']=='Movie') & (data['listed_in']=='Comedies') | (data['country']=='United Kingdom')]
# Out:
#      show_id     type                          title  \
# 5         s9  TV Show  The Great British Baking Show
# 16      s913    Movie    The Circle - The Afterparty
# 30       s28    Movie                      Grown Ups
# 114      s95    Movie                      Show Dogs
# 169     s116    Movie                    Bright Star
# ...      ...      ...                            ...
# 8762   s8647  TV Show                     Twirlywoos
# 8769   s8713  TV Show     Weird Wonders of the World
# 8775   s8741  TV Show                    Wild Alaska
# 8776   s8742  TV Show                    Wild Arabia
# 8780   s8759  TV Show         World's Busiest Cities
#
#                              director         country date_added  \
# 5                     Andy Devonshire  United Kingdom  9/24/2021
# 16    Krysia Plonka, Kristian Mercado   United States   5/7/2021
# 30                       Dennis Dugan   United States  9/20/2021
# ...

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
# In how many Movies/shows directed by Suhas Kadav
data [(data['director']=='Suhas Kadav')]
# Out:
#      show_id   type                                              title  \
# 7       s939  Movie                    Motu Patlu in the Game of Zones
# 9       s940  Movie                           Motu Patlu in Wonderland
# 10      s941  Movie                     Motu Patlu: Deep Sea Adventure
# 11      s942  Movie                           Motu Patlu: Mission Moon
# 987     s938  Movie                       Motu Patlu in Dragon's World
# 1022   s1007  Movie                           Motu Patlu Dino Invasion
# 1023   s1008  Movie                        Motu Patlu in Octupus World
# 1027   s1009  Movie                            Motu Patlu VS Robo Kids
# 1064   s1072  Movie           Motu Patlu in Hong Kong: Kung Fu Kings 3
# 1066   s1073  Movie                     Motu Patlu in the City of Gold
# 1067   s1074  Movie  Motu Patlu Kung Fu Kings 4 The Challenge of Ku...
# 1069   s1075  Movie  Motu Patlu the Superheroes – Super Villains fr...
# ...

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
data.rating.nunique()    # How many different ratings in total defined by Netflix
# Out:
# 14

# %%
data.rating.unique()    # All unique rating types are here
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', 'TV-14', 'TV-Y7', 'TV-Y', 'PG', 'TV-G',
#        'R', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
# How many Movies got the 'TV-14' rating in Canada.
data[(data.type=='Movie') & (data.rating=='TV-14') & (data.country=='Canada')].shape
# Out:
# (21, 12)

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
# How many Movies got 'NR' rating after 2000
data[(data.type=='Movie') & (data.rating=='NR') & (data.Year>2000)]
# Out:
#      show_id   type                       title  \
# 4265   s5972  Movie                    (T)ERROR
# 4275   s5988  Movie                  13 Cameras
# 4300   s6016  Movie                 4th Man Out
# 4335   s6055  Movie  A Russell Peters Christmas
# 4366   s6088  Movie            Act of Vengeance
# ...      ...    ...                         ...
# 6435   s8675  Movie             Viceroy's House
# 6442   s8683  Movie             Vizontele Tuuba
# 6480   s8728  Movie       When Hari Got Married
# 6498   s8749  Movie        Winter of Our Dreams
# 6534   s8793  Movie                 Young Tiger
#
#                                     director         country  date_added  \
# 4265  Lyric R. Cabral, David Felix Sutcliffe   United States   6/30/2016
# 4275                          Victor Zarcoff   United States   8/13/2016
# 4300                          Andrew Nackman   United States    5/5/2016
# 4335                      Henry Sarwer-Foner          Canada   11/1/2013
# ...

# %%
# Count of all Movies
data[(data.type=='Movie') & (data.rating=='NR') & (data.Year>2000)].shape
# Out:
# (75, 12)

# %%
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year
# 0                                      Documentaries 2021-09-25  2021
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021

# %%
# Now Want to check the highest duration of Movie or Tv show
# Firstly checking the unique durations
data.duration.unique()
# Out:
# array(['90 min', '1 Season', '91 min', '125 min', '9 Seasons', '104 min',
#        '87 min', '127 min', '76 min', '71 min', '131 min', '39 min',
#        '36 min', '34 min', '35 min', '46 min', '67 min', '65 min',
#        '61 min', '166 min', '103 min', '97 min', '106 min', '2 Seasons',
#        '4 Seasons', '147 min', '94 min', '161 min', '111 min', '110 min',
#        '105 min', '96 min', '124 min', '116 min', '98 min', '115 min',
#        '122 min', '55 min', '99 min', '88 min', '100 min', '6 Seasons',
#        '3 Seasons', '23 min', '102 min', '93 min', '95 min', '85 min',
#        '83 min', '182 min', '5 Seasons', '92 min', '84 min', '48 min',
#        '145 min', '119 min', '80 min', '128 min', '143 min', '273 min',
#        '117 min', '114 min', '118 min', '108 min', '37 min', '121 min',
#        '63 min', '142 min', '113 min', '154 min', '120 min', '82 min',
#        '109 min', '101 min', '86 min', '77 min', '229 min', '15 min',
# ...

# %%
data.duration.dtypes    # checking the type of durations that is 'object'
# Out:
# dtype('O')

# %%
# Now make two new columns Minutes and Units where we split the durations For example: if duration is "90 min" the '90' will
# be in 'Minutes'  column and 'min' will be in Units column
data[['Minutes','Units']]= data.duration.str.split(' ', expand=True)

# %%
# Here it is the Two new Columns at end
data.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in     R_Date  Year Minutes  \
# 0                                      Documentaries 2021-09-25  2021      90
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021       1
#
#     Units
# 0     min
# 1  Season

# %%
# Now using max() easily filter the maximum duration values
data.Minutes.max()
# Out:
# '99'
